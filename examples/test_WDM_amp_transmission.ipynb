# %% [markdown]
# <a href="https://colab.research.google.com/github/peymanplvnzd47/-VQE-for-Hamiltonian-simulation/blob/main/examples/test_WDM_amp_transmission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/edsonportosilva/OptiCommPy/blob/main/jupyter/test_WDM_transmission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulation of coherent WDM transmission

# %%
if 'google.colab' in str(get_ipython()):
    ! git clone -b main https://github.com/edsonportosilva/OptiCommPy
    from os import chdir as cd
    cd('/content/OptiCommPy/')
    ! pip install .
# Out:
# Cloning into 'OptiCommPy'...
# remote: Enumerating objects: 10903, done.
# remote: Counting objects: 100% (1704/1704), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 10903 (delta 1579), reused 1557 (delta 1491), pack-reused 9199 (from 1)
# Receiving objects: 100% (10903/10903), 197.61 MiB | 17.34 MiB/s, done.
# Resolving deltas: 100% (8191/8191), done.
# Processing /content/OptiCommPy
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from OptiCommPy==0.9.0) (2.0.2)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from OptiCommPy==0.9.0) (1.15.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from OptiCommPy==0.9.0) (3.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from OptiCommPy==0.9.0) (1.13.1)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from OptiCommPy==0.9.0) (4.67.1)
# Requirement already satisfied: numba>=0.54.0 in /usr/local/lib/python3.11/dist-packages (from OptiCommPy==0.9.0) (0.60.0)
# Collecting simple-pid>=1.0.1 (from OptiCommPy==0.9.0)
#   Downloading simple_pid-2.0.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting mpl-scatter-density>=0.7.0 (from OptiCommPy==0.9.0)
#   Downloading mpl_scatter_density-0.8-py3-none-any.whl.metadata (12 kB)
# Collecting sphinx-rtd-theme>=1.2.2 (from OptiCommPy==0.9.0)
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nbsphinx>=0.9.3 (from OptiCommPy==0.9.0)
#   Downloading nbsphinx-0.9.7-py3-none-any.whl.metadata (2.3 kB)
# Collecting nbsphinx-link>=1.3.0 (from OptiCommPy==0.9.0)
#   Downloading nbsphinx_link-1.3.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.9.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.9.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.9.0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.9.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.9.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.9.0) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.9.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.9.0) (2.9.0.post0)
# Collecting fast-histogram>=0.3 (from mpl-scatter-density>=0.7.0->OptiCommPy==0.9.0)
#   Downloading fast_histogram-0.14-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: docutils>=0.18.1 in /usr/local/lib/python3.11/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.9.0) (0.21.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.9.0) (3.1.6)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in /usr/local/lib/python3.11/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.9.0) (7.16.6)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.11/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.9.0) (5.7.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.9.0) (5.10.4)
# Collecting sphinx<8.2,>=1.8 (from nbsphinx>=0.9.3->OptiCommPy==0.9.0)
#   Downloading sphinx-8.1.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54.0->OptiCommPy==0.9.0) (0.43.0)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme>=1.2.2->OptiCommPy==0.9.0)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->OptiCommPy==0.9.0) (1.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.19.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->OptiCommPy==0.9.0) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.32.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.7->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (4.3.8)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (6.1.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx<8.2,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (4.13.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (24.0.1)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.9.0) (6.4.2)
# Downloading mpl_scatter_density-0.8-py3-none-any.whl (749 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.5/749.5 kB 51.1 MB/s eta 0:00:00
# Downloading nbsphinx-0.9.7-py3-none-any.whl (31 kB)
# Downloading nbsphinx_link-1.3.1-py3-none-any.whl (5.2 kB)
# Downloading simple_pid-2.0.1-py3-none-any.whl (7.2 kB)
# Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 127.2 MB/s eta 0:00:00
# Downloading fast_histogram-0.14-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 6.8 MB/s eta 0:00:00
# Downloading sphinx-8.1.3-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 123.5 MB/s eta 0:00:00
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 15.3 MB/s eta 0:00:00
# Building wheels for collected packages: OptiCommPy
#   Building wheel for OptiCommPy (setup.py) ... done
#   Created wheel for OptiCommPy: filename=OptiCommPy-0.9.0-py3-none-any.whl size=81662 sha256=d9851063b1743abc40631ace261af082637d4b160bbdf9401f560c28f9f5e238
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jbhwwuc5/wheels/0a/b3/b4/c1f785c2fbf2de32a986f34e6d5146d854df27f3012a7f465d
# Successfully built OptiCommPy
# Installing collected packages: simple-pid, fast-histogram, sphinx, sphinxcontrib-jquery, mpl-scatter-density, sphinx-rtd-theme, nbsphinx, nbsphinx-link, OptiCommPy
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 8.2.3
#     Uninstalling Sphinx-8.2.3:
#       Successfully uninstalled Sphinx-8.2.3
# Successfully installed OptiCommPy-0.9.0 fast-histogram-0.14 mpl-scatter-density-0.8 nbsphinx-0.9.7 nbsphinx-link-1.3.1 simple-pid-2.0.1 sphinx-8.1.3 sphinx-rtd-theme-3.0.2 sphinxcontrib-jquery-4.1

# %%
import matplotlib.pyplot as plt
import numpy as np

from optic.dsp.core import pulseShape, firFilter, decimate, symbolSync, pnorm, signal_power
from optic.models.devices import pdmCoherentReceiver, basicLaserModel

try:
    from optic.dsp.coreGPU import checkGPU
    if checkGPU():
        from optic.dsp.coreGPU import firFilter
        from optic.models.modelsGPU import manakovSSF
    else:
        from optic.dsp.core import firFilter
        from optic.models.channels import manakovSSF
except ImportError:
    from optic.dsp.core import firFilter
    from optic.models.channels import manakovSSF

from optic.models.tx import simpleWDMTx
from optic.utils import parameters
from optic.dsp.equalization import edc, mimoAdaptEqualizer
from optic.dsp.carrierRecovery import cpr
from optic.comm.metrics import fastBERcalc, monteCarloGMI, monteCarloMI, calcEVM
from optic.plot import pconst

import scipy.constants as const

from optic.models.amplification import edfaSM,OSA

import os.path as path
# Out:
# /usr/local/lib/python3.11/dist-packages/cupyx/jit/_interface.py:173: FutureWarning: cupyx.jit.rawkernel is experimental. The interface can change in the future.
#   cupy._util.experimental('cupyx.jit.rawkernel')

# %%
import logging as logg
logg.getLogger().setLevel(logg.INFO)
logg.basicConfig(format='%(message)s')

# %%
from IPython.core.display import HTML
from IPython.core.pylabtools import figsize

# %%
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")

figsize(10, 3)

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler

# %% [markdown]
# ## Parameters

# %%
# Transmitter parameters:
paramTx = parameters()
paramTx.M   = 16           # order of the modulation format
paramTx.Rs  = 32e9         # symbol rate [baud]
paramTx.SpS = 16           # samples per symbol
paramTx.pulse = 'rrc'      # pulse shaping filter
paramTx.Ntaps = 2*4096     # number of pulse shaping filter coefficients
paramTx.alphaRRC = 0.5    # RRC rolloff
paramTx.Pch_dBm = -2        # power per WDM channel [dBm]
paramTx.Nch     = 11       # number of WDM channels
paramTx.Fc      = 193.1e12 # central optical frequency of the WDM spectrum
paramTx.lw      = 100e3    # laser linewidth in Hz
paramTx.freqSpac = 37.5e9  # WDM grid spacing
paramTx.Nmodes = 2         # number of signal modes [2 for polarization multiplexed signals]
paramTx.Nbits = int(np.log2(paramTx.M)*1e5) # total number of bits per polarization

# %%
# Optical channel parameters:
paramCh = parameters()
paramCh.Ltotal = 100      # total link distance [km]
paramCh.Lspan  = 100      # span length [km]
paramCh.alpha  = 0.2     # fiber loss parameter [dB/km]
paramCh.D = 16           # fiber dispersion parameter [ps/nm/km]
paramCh.gamma = 1.3      # fiber nonlinear parameter [1/(W.km)]
paramCh.Fc = paramTx.Fc  # central optical frequency of the WDM spectrum
paramCh.hz = 0.5         # step-size of the split-step Fourier method [km]
paramCh.maxIter = 5      # maximum number of convergence iterations per step
paramCh.tol = 1e-5       # error tolerance per step
paramCh.prgsBar = True   # show progress bar?
paramCh.amp = None
paramCh.Fs = paramTx.Rs*paramTx.SpS # sampling rate

Fs = paramCh.Fs

# %%
# EDFA parameters
param_edfa = parameters()
# gain control
param_edfa.type     = "AGC"
param_edfa.value    = 20
# pid - gain control
param_edfa.kp = 1e-2
param_edfa.ki = 1e-2
param_edfa.kd = 5e-2
# pump information
param_edfa.forPump  = {'pump_signal': np.array([100e-3]), 'pump_lambda': np.array([980e-9])}
param_edfa.bckPump  = {'pump_signal': np.array([000e-3]), 'pump_lambda': np.array([980e-9])}
# giles parameters
param_edfa.file     = 'giles_MP980.dat'
param_edfa.fileunit = 'nm'
param_edfa.gmtc     = 'Bessel'
param_edfa.tol      = 3/100
param_edfa.tolCtrl  = 0.5
param_edfa.noiseBand= 12.5e9

# %%
if 'google.colab' in str(get_ipython()):
  param_edfa.file = path.join(path.abspath(path.join("../")), 'OptiCommPy', 'optic', 'models', 'ampParams', param_edfa.file)
else:
  param_edfa.file = path.join(path.abspath(path.join("../")), 'optic', 'models', 'ampParams', param_edfa.file)

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Singal generation, propagation, amplification and reception

# %% [markdown]
# **Polarization multiplexed WDM signal generation**

# %%
# generate WDM signal
sigWDM_Tx, symbTx_, paramTx = simpleWDMTx(paramTx)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# INFO:root:channel 0	 fc : 192.9125 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 0	 power: -2.00 dBm
#
# INFO:root:channel 1	 fc : 192.9500 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 1	 power: -2.00 dBm
#
# INFO:root:channel 2	 fc : 192.9875 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 2	 power: -2.00 dBm
#
# INFO:root:channel 3	 fc : 193.0250 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 3	 power: -2.00 dBm
#
# INFO:root:channel 4	 fc : 193.0625 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 4	 power: -2.00 dBm
#
# INFO:root:channel 5	 fc : 193.1000 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 5	 power: -2.00 dBm
#
# INFO:root:channel 6	 fc : 193.1375 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 6	 power: -2.00 dBm
#
# INFO:root:channel 7	 fc : 193.1750 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 7	 power: -2.00 dBm
#
# INFO:root:channel 8	 fc : 193.2125 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 8	 power: -2.00 dBm
#
# INFO:root:channel 9	 fc : 193.2500 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 9	 power: -2.00 dBm
#
# INFO:root:channel 10	 fc : 193.2875 THz
# INFO:root:  mode #0	 power: -5.01 dBm
# INFO:root:  mode #1	 power: -5.01 dBm
# INFO:root:channel 10	 power: -2.00 dBm
#
# INFO:root:total WDM signal power: 8.41 dBm

# %%
print('Average power of the modulated optical signal [mW]: %.3f mW'%(signal_power(sigWDM_Tx)/1e-3))
print('Average power of the modulated optical signal [dBm]: %.3f dBm'%(10*np.log10(signal_power(sigWDM_Tx)/1e-3)))
# Out:
# Average power of the modulated optical signal [mW]: 6.941 mW
# Average power of the modulated optical signal [dBm]: 8.414 dBm

# %%
ax = OSA(sigWDM_Tx, Fs, paramTx.Fc)
ax.set_xlim([1550,1555])
ax.set_ylim([-80,-40])
# Out:
# (-80.0, -40.0)

# %% [markdown]
# **Nonlinear fiber propagation with the split-step Fourier method**

# %%
# nonlinear signal propagation
sigWDM = manakovSSF(sigWDM_Tx, paramCh)
# Out:
# INFO:root:Running Manakov SSF model on GPU...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ax = OSA(sigWDM, Fs, paramTx.Fc)
ax.set_xlim([1550,1555])
ax.set_ylim([-80,-40])
# Out:
# (-80.0, -40.0)

# %%
prog_pw = signal_power(sigWDM)/1e-3 #np.sum(1000*np.mean(sigWDM * np.conj(sigWDM), axis = 0).real)
print('Average power of the modulated optical signal [mW]: %.3f mW'%(prog_pw))
print('Average power of the modulated optical signal [dBm]: %.3f dBm'%(10*np.log10(prog_pw)))
# Out:
# Average power of the modulated optical signal [mW]: 0.069 mW
# Average power of the modulated optical signal [dBm]: -11.586 dBm

# %% [markdown]
# **Optical amplification using an EDFA**

# %%
sigWDM_Amp, PumpF, PumpB, noisef  = edfaSM(sigWDM, Fs, paramTx.Fc, param_edfa)
# Out:
# INFO:root:
# EDF absorption and gain coeficients. Calculating absorption and emission cross-section ...
# INFO:root:EDFA SM: loop  1
# INFO:root:Convergence: 0.027%.
#
# INFO:root:EDFA SM: control loop  1
# INFO:root:Convergence: 6.479 dB
# INFO:root:Pump for.: 50.00 mW
#
# INFO:root:EDFA SM: loop  1
# INFO:root:Convergence: -99.708%.
#
# INFO:root:EDFA SM: loop  2
# INFO:root:Convergence: 1.023%.
#
# INFO:root:EDFA SM: control loop  2
# INFO:root:Convergence: 3.597 dB
# INFO:root:Pump for.: 25.00 mW
#
# INFO:root:EDFA SM: loop  1
# INFO:root:Convergence: -98.100%.
#
# INFO:root:EDFA SM: loop  2
# INFO:root:Convergence: -0.307%.

# %%
rx_pw = 1e3*signal_power(sigWDM_Amp)
print('Forward pump  - [mW] : %.3f' %(1e3*PumpF[0]))
print('Backward pump - [mW] : %.3f' %(1e3*PumpB[1]))
print('Average power - RX amp [mW] : %.3f' %(rx_pw))
print('Average power - RX amp [dBm] : %.3f' %(10*np.log10(rx_pw)))
print('Gain [dB]: %.3f' %(10*np.log10(rx_pw/prog_pw)))
# Out:
# Forward pump  - [mW] : 25.000
# Backward pump - [mW] : 0.000
# Average power - RX amp [mW] : 6.808
# Average power - RX amp [dBm] : 8.330
# Gain [dB]: 19.916

# %%
ax = OSA(sigWDM_Amp, Fs, paramTx.Fc)
ax.set_xlim([1550,1555])
ax.set_ylim([-80,-40])
# Out:
# (-80.0, -40.0)

# %% [markdown]
# **Optical WDM spectrum before and after transmission**

# %%
# plot psd
plt.figure(figsize=(10, 3))
plt.xlim(paramCh.Fc-Fs/2,paramCh.Fc+Fs/2);
plt.psd(sigWDM_Tx[:,0], Fs=Fs, Fc=paramCh.Fc, NFFT = 4*1024, sides='twosided', label = 'WDM spectrum - Tx')
plt.psd(sigWDM[:,0], Fs=Fs, Fc=paramCh.Fc, NFFT = 4*1024, sides='twosided', label = 'WDM spectrum - Rx')
plt.psd(sigWDM_Amp[:,0], Fs=Fs, Fc=paramCh.Fc, NFFT = 4*1024, sides='twosided', label = 'WDM spectrum - Amp - Rx')
plt.legend(loc='lower left')
plt.title('optical WDM spectrum');

# %% [markdown]
# **WDM channels coherent detection and demodulation**

# %%
# parameters
chIndex  = int(np.floor(paramTx.Nch/2))      # index of the channel to be demodulated

freqGrid = paramTx.freqGrid
π  = np.pi
t  = np.arange(0, len(sigWDM))*1/Fs

print('Demodulating channel #%d , fc: %.4f THz, λ: %.4f nm\n'\
      %(chIndex, (paramCh.Fc + freqGrid[chIndex])/1e12, const.c/(paramCh.Fc + freqGrid[chIndex])/1e-9))

symbTx = symbTx_[:,:,chIndex]

# local oscillator (LO) parameters:
FO      = 150e6                 # frequency offset
Δf_lo   = freqGrid[chIndex]+FO  # downshift of the channel to be demodulated

# generate CW laser LO field
paramLO = parameters()
paramLO.P = 10              # power in dBm
paramLO.lw = 100e3          # laser linewidth
paramLO.RIN_var = 0
paramLO.Ns = len(sigWDM)
paramLO.Fs = Fs

sigLO = basicLaserModel(paramLO)
sigLO = sigLO*np.exp(1j*2*π*Δf_lo*t) # add frequency offset

print('Local oscillator P: %.2f dBm, lw: %.2f kHz, FO: %.2f MHz\n'\
      %(paramLO.P, paramLO.lw/1e3, FO/1e6))
# Out:
# Demodulating channel #5 , fc: 193.1000 THz, λ: 1552.5244 nm
#
# Local oscillator P: 10.00 dBm, lw: 100.00 kHz, FO: 150.00 MHz

# %% [markdown]
# **polarization multiplexed coherent optical receiver**

# %%
# photodiodes parameters
paramPD = parameters()
paramPD.B = paramTx.Rs
paramPD.Fs = Fs
paramPD.ideal = True

θsig = π/3 # polarization rotation angle
sigRx = pdmCoherentReceiver(sigWDM_Amp, sigLO, θsig, paramPD)

# plot received constellations
pconst(sigRx[0::paramTx.SpS,:], R=3);

# %% [markdown]
# **Matched filtering and CD compensation**

# %%
# Matched filtering
if paramTx.pulse == 'nrz':
    pulse = pulseShape('nrz', paramTx.SpS)
elif paramTx.pulse == 'rrc':
    pulse = pulseShape('rrc', paramTx.SpS, N=paramTx.Ntaps, alpha=paramTx.alphaRRC, Ts=1/paramTx.Rs)

pulse = pnorm(pulse)
sigRx = firFilter(pulse, sigRx)

# plot constellations after matched filtering
pconst(sigRx[0::paramTx.SpS,:], R=3);

# %%
# CD compensation
paramEDC = parameters()
paramEDC.L = paramCh.Ltotal
paramEDC.D = paramCh.D
paramEDC.Fc = paramCh.Fc-Δf_lo
paramEDC.Fs = Fs

sigRx = edc(sigRx, paramEDC)

# plot constellations after CD compensation
pconst(sigRx[0::paramTx.SpS,:], R=3);
# Out:
# INFO:root:Running CD compensation...
# INFO:root:CD filter length: 448 taps, FFT size: 512

# %% [markdown]
# **Downsampling to 2 samples/symbol and re-synchronization with transmitted sequences**

# %%
# decimation
paramDec = parameters()
paramDec.SpS_in  = paramTx.SpS
paramDec.SpS_out = 2
sigRx = decimate(sigRx, paramDec)

symbRx = symbolSync(sigRx, symbTx, 2)

# %% [markdown]
# **Power normalization**

# %%
x = pnorm(sigRx)
d = pnorm(symbRx)

# %% [markdown]
# **Adaptive equalization**

# %%
# adaptive equalization parameters
paramEq = parameters()
paramEq.nTaps = 15
paramEq.SpS = paramDec.SpS_out
paramEq.numIter = 5
paramEq.storeCoeff = False
paramEq.M = paramTx.M
paramEq.L = [int(0.2*d.shape[0]), int(0.8*d.shape[0])]
paramEq.prgsBar = False

if paramTx.M == 4:
    paramEq.alg = ['nlms','cma'] # QPSK
    paramEq.mu = [5e-3, 1e-3]
else:
    paramEq.alg = ['da-rde','rde'] # M-QAM
    paramEq.mu = [5e-3, 2e-4]

y_EQ = mimoAdaptEqualizer(x, paramEq, d)

#plot constellations after adaptive equalization
discard = 5000
pconst(y_EQ[discard:-discard,:]);
# Out:
# INFO:root:Running adaptive equalizer...
# INFO:root:da-rde - training stage #0
# INFO:root:da-rde pre-convergence training iteration #0
# INFO:root:da-rde MSE = 0.008820.
# INFO:root:da-rde pre-convergence training iteration #1
# INFO:root:da-rde MSE = 0.006677.
# INFO:root:da-rde pre-convergence training iteration #2
# INFO:root:da-rde MSE = 0.006611.
# INFO:root:da-rde pre-convergence training iteration #3
# INFO:root:da-rde MSE = 0.006573.
# INFO:root:da-rde pre-convergence training iteration #4
# INFO:root:da-rde MSE = 0.006550.
# INFO:root:rde - training stage #1
# INFO:root:rde MSE = 0.005174.

# %% [markdown]
# **Carrier phase recovery**

# %%
paramCPR = parameters()
paramCPR.alg = 'bps'
paramCPR.M   = paramTx.M
paramCPR.N   = 75
paramCPR.B   = 64

y_CPR = cpr(y_EQ, paramCPR)

discard = 500

#plot constellations after CPR
pconst([y_CPR[discard:-discard,:],d[discard:-discard,:]], pType='fast')
pconst(y_CPR[discard:-discard,:]);
# Out:
# INFO:root:Running frequency offset compensation...
# INFO:root:Running BPS carrier phase recovery...

# %% [markdown]
# ### Evaluate transmission metrics

# %%
ind = np.arange(discard, d.shape[0]-discard)
BER, SER, SNR = fastBERcalc(y_CPR[ind,:], d[ind,:], paramTx.M, 'qam')
GMI, NGMI = monteCarloGMI(y_CPR[ind,:], d[ind,:], paramTx.M, 'qam')
MI       = monteCarloMI(y_CPR[ind,:], d[ind,:], paramTx.M, 'qam')
EVM      = calcEVM(y_CPR[ind,:], paramTx.M, 'qam', d[ind,:])

print('      pol.X      pol.Y      ')
print(' SER: %.2e,  %.2e'%(SER[0], SER[1]))
print(' BER: %.2e,  %.2e'%(BER[0], BER[1]))
print(' SNR: %.2f dB,  %.2f dB'%(SNR[0], SNR[1]))
print(' EVM: %.2f %%,    %.2f %%'%(EVM[0]*100, EVM[1]*100))
print('  MI: %.2f bits, %.2f bits'%(MI[0], MI[1]))
print(' GMI: %.2f bits, %.2f bits'%(GMI[0], GMI[1]))
print('NGMI: %.2f,      %.2f'%(NGMI[0], NGMI[1]))
# Out:
#       pol.X      pol.Y
#  SER: 0.00e+00,  0.00e+00
#  BER: 0.00e+00,  0.00e+00
#  SNR: 25.28 dB,  25.27 dB
#  EVM: 0.30 %,    0.30 %
#   MI: 4.00 bits, 4.00 bits
#  GMI: 4.00 bits, 4.00 bits
# NGMI: 1.00,      1.00
